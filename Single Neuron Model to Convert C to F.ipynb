# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# In this project, we will create a basic machine learning model to convert temperatures from Celsius to Fahrenheit using the equation T(°F) = T(°C) × 9/5 + 32. For instance, to convert 0°C to Fahrenheit, we apply the formula: (0°C × 9/5) + 32, resulting in 32°F.

# %% [markdown]
# <table>
#   <tr><td>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/7/70/Thermometer_CF.svg"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1. Convert Celsius to Fahrenheit [Image Source: https://commons.wikimedia.org/wiki/File:Thermometer_CF.svg]
#   </td></tr>
# </table>

# %% [markdown]
# # STEP #0: IMPORT LIBRARIES

# %%
# !pip3 install --upgrade pip
# !pip3 install tensorflow==2.15.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 48.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # STEP #1: IMPORT DATASETS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# You have to include the full link to the csv file containing your dataset
Temperature_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TensorFlow/Celsius+to+Fahrenheit.csv')
Temperature_df.reset_index(drop=True, inplace=True)

# %%
Temperature_df.head(5)
# Out:
#    Celsius  Fahrenheit
# 0      -50       -58.0
# 1      -40       -40.0
# 2      -30       -22.0
# 3      -20        -4.0
# 4      -10        14.0

# %%
Temperature_df.tail(10)
# Out:
#     Celsius  Fahrenheit
# 20        6        42.8
# 21        7        44.6
# 22        8        46.4
# 23        9        48.2
# 24       10        50.0
# 25       20        68.0
# 26       30        86.0
# 27       40       104.0
# 28       50       122.0
# 29       60       140.0

# %%
Temperature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Celsius     30 non-null     int64
#  1   Fahrenheit  30 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
Temperature_df.describe()
# Out:
#          Celsius  Fahrenheit
# count  30.000000   30.000000
# mean    2.000000   35.600000
# std    22.780815   41.005466
# min   -50.000000  -58.000000
# 25%    -6.750000   19.850000
# 50%     0.500000   32.900000
# 75%     7.750000   45.950000
# max    60.000000  140.000000

# %% [markdown]
# # STEP #2: VISUALIZE DATASET

# %%
sns.scatterplot(data=Temperature_df, x='Celsius', y='Fahrenheit')
# Out:
# <Axes: xlabel='Celsius', ylabel='Fahrenheit'>

# %% [markdown]
# # STEP #3: CREATE TESTING AND TRAINING DATASET

# %%
X_train = Temperature_df['Celsius']
y_train = Temperature_df['Fahrenheit']

# %% [markdown]
# # STEP#4: BUILD AND TRAIN THE MODEL

# %%
X_train.shape
# Out:
# (30,)

# %%
y_train.shape
# Out:
# (30,)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=[1]))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.5), loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - loss: 0.1319
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 118.6008
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 7.8554
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 27.1941
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 68.2826
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 48.9511
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 12.2599
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5906
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 17.3441
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33.7942
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 29.9297
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 13.1052
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.0335
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.0141
# Epoch 15/100
# ...

# %% [markdown]
# # STEP#5: EVALUATING THE MODEL

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend(['Training Loss'])

# %%
model.get_weights()
# Out:
# [array([[1.7998401]], dtype=float32), array([31.999413], dtype=float32)]

# %% [markdown]
# ## Use the trained model to perform predictions

# %%
Temp_C = np.array([[0]])
Temp_F = model.predict(Temp_C)
print('Temperature in degF Using Trained ANN =', Temp_F[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Temperature in degF Using Trained ANN = 31.999413

# %% [markdown]
# ## Let's confirm this Using the equation:

# %%
Temp_F = 9/5 * Temp_C + 32
print('Temperature in degF Using Equation =', Temp_F)
# Out:
# Temperature in degF Using Equation = [[32.]]
